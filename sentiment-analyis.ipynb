# %%
import pandas as pd

# %%
books = pd.read_csv("books_with_categories.csv")

# %%
from transformers import pipeline
classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", device=0,
                      top_k=None)
classifier("I love this!")
# Out:
# Device set to use cpu
# [[{'label': 'joy', 'score': 0.9771687984466553},
#   {'label': 'surprise', 'score': 0.008528691716492176},
#   {'label': 'neutral', 'score': 0.005764589179307222},
#   {'label': 'anger', 'score': 0.004419791977852583},
#   {'label': 'sadness', 'score': 0.002092393347993493},
#   {'label': 'disgust', 'score': 0.001611992483958602},
#   {'label': 'fear', 'score': 0.0004138525982853025}]]

# %%
sentences = books["description"][0].split(".")

predictions = classifier(sentences)

# %%
sentences[0]
# Out:
# '"In The Problem of Pain, C'

# %%
predictions[0]
# Out:
# [{'label': 'surprise', 'score': 0.7296021580696106},
#  {'label': 'neutral', 'score': 0.14038598537445068},
#  {'label': 'fear', 'score': 0.06816227734088898},
#  {'label': 'joy', 'score': 0.04794260486960411},
#  {'label': 'anger', 'score': 0.009156367741525173},
#  {'label': 'disgust', 'score': 0.0026284768246114254},
#  {'label': 'sadness', 'score': 0.002122163772583008}]

# %%
sorted(predictions[0], key=lambda x: x["label"])
# Out:
# [{'label': 'anger', 'score': 0.0028371873777359724},
#  {'label': 'disgust', 'score': 0.0031369959469884634},
#  {'label': 'fear', 'score': 0.001166273606941104},
#  {'label': 'joy', 'score': 0.9585494995117188},
#  {'label': 'neutral', 'score': 0.02825154736638069},
#  {'label': 'sadness', 'score': 0.0029162862338125706},
#  {'label': 'surprise', 'score': 0.003142274683341384}]

# %%
import numpy as np 

emotion_labels = ["anger", "disgust", "fear", "joy", "neutral" ,"sadness", "surprise"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

# %%
def calculate_max_emotions_scores(predictions):
    per_emotion_scores = {label: [] for label in emotion_labels}
    for prediction in predictions:
        sorted_prediction = sorted(prediction, key=lambda x: x["label"])
        for index,label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_prediction[index]["score"])
    return {label: np.max(scores) for label,scores in per_emotion_scores.items()}

# %%
from tqdm import tqdm

# %%
emotion_labels = ["anger", "disgust", "fear", "joy", "neutral" ,"sadness", "surprise"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

for i in tqdm(range(5)):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotions_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
#  40%|████      | 2/5 [00:00<00:00,  6.73it/s]
# {'anger': [0.009156367741525173, 0.04047833010554314, 0.011031905189156532, 0.03219081461429596, 0.001842890284024179, 0.005024968180805445, 0.0048213074915111065, 0.06413363665342331], 'disgust': [0.0026284768246114254, 0.27359113097190857, 0.043422672897577286, 0.008431807160377502, 0.00648059556260705, 0.0377170704305172, 0.006512214429676533, 0.10400673747062683], 'fear': [0.06816227734088898, 0.006879049818962812, 0.014084091410040855, 0.9281682968139648, 0.005393987521529198, 0.0005423057009465992, 0.003529018023982644, 0.051362838596105576], 'joy': [0.04794260486960411, 0.1090831384062767, 0.014211490750312805, 0.0010455832816660404, 0.0017338779289275408, 0.9327981472015381, 0.6528705954551697, 0.04056441783905029], 'neutral': [0.14038598537445068, 0.4493706524372101
# {'anger': [0.01603621058166027, 0.006699252407997847, 0.35148516297340393, 0.06413363665342331], 'disgust': [0.060695115476846695, 0.003018265124410391, 0.1507222205400467, 0.10400673747062683], 'fear': [0.0016916367458179593, 0.0019178647780790925, 0.36070549488067627, 0.051362838596105576], 'joy': [0.16175726056098938, 0.25188156962394714, 0.003223198698833585, 0.04056441783905029], 'neutral': [0.7326849102973938, 0.7030512094497681, 0.07967229932546616, 0.549476683139801], 'sadness': [0.020988235250115395, 0.0037486066576093435, 0.04976692423224449, 0.11169019341468811], 'surprise': [0.006146568339318037, 0.02968321181833744, 0.004424642771482468, 0.07876546680927277]}
# {'anger': [0.013624400831758976, 0.05883365124464035, 0.0814124271273613, 0.05883365124464035, 0.026564821600914, 0.006978122051805258, 0.06413363665342331], 'disgust': [0.1222427561879158, 0.07331304252147675, 0.18449550867080688, 0.07331304252147675, 0.01625637896358967, 0.007403695024549961, 0.10400673747062683], 'fear': [0.09504342079162598, 0.0401952750980854, 0.0063834949396550655, 0.0401952750980854, 0.005682759918272495, 0.0031399079598486423, 0.051362838596105576], 'joy': [0.008335691876709461, 0.02480991929769516, 0.03520696982741356, 0.02480991929769516, 0.025416051968932152, 0.011516422964632511, 0.04056441783905029], 'neutral': [0.27261361479759216, 0.567668080329895, 0.6389604806900024, 0.567668080329895, 0.8843895196914673, 0.8802324533462524, 0.549476683139801], 'sadness': [0.4758801758289337, 0.16030186414718628, 0.0477098673582077, 0.16030186414718628, 0.03498145937919617, 0.02083715610206127, 0.11169019341468811], 'surprise': [0.01225984375923872, 0.07487812638282776, 0.005831237882375717, 0.07487812638282776, 0.006708973553031683, 0.06989232450723648, 0.07876546680927277]}

# %%
emotion_labels = ["anger", "disgust", "fear", "joy", "neutral" ,"sadness", "surprise"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

for i in tqdm(range(len(books))):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotions_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# 100%|██████████| 5197/5197 [05:37<00:00, 15.38it/s]

# %%
emotions_df  = pd.DataFrame(emotion_scores)
emotions_df["isbn13"] = isbn

# %%
books = books.merge(emotions_df, on="isbn13")
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ...  \
# 0               3.85      247.0  ...
# 1               3.83      241.0  ...
# 2               3.93      512.0  ...
# 3               4.15      170.0  ...
# 4               4.09      176.0  ...
# ...              ...        ...  ...
# 5192            2.93      324.0  ...
# 5193            3.70      175.0  ...
# 5194            3.82      198.0  ...
# 5195            4.51      531.0  ...
# 5196            0.00      210.0  ...
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories  \
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
# ...                                                 ...               ...
# 5192  9788172235222 On A Train Journey Home To North...           Fiction
# 5193  9788173031014 This book tells the tale of a ma...        Nonfiction
# 5194  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5195  9788185300535 This collection of the timeless ...        Nonfiction
# 5196  9789027712059 Since the three volume edition o...        Nonfiction
#
#          anger   disgust      fear       joy   neutral   sadness  surprise
# 0     0.064134  0.273591  0.928168  0.932798  0.646216  0.967158  0.729602
# 1     0.612619  0.348284  0.942528  0.704422  0.887940  0.111690  0.252546
# 2     0.064134  0.104007  0.972321  0.767239  0.549477  0.111690  0.078765
# 3     0.351485  0.150722  0.360705  0.251882  0.732685  0.111690  0.078765
# 4     0.081412  0.184496  0.095043  0.040564  0.884390  0.475880  0.078765
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148209  0.030643  0.919165  0.255171  0.853721  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400263  0.883198  0.111690  0.227765
# 5194  0.009997  0.009929  0.339218  0.947779  0.375754  0.066685  0.057625
# 5195  0.064134  0.104007  0.459270  0.759457  0.951104  0.368111  0.078765
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078765
#
# [5197 rows x 21 columns]

# %%
books.to_csv("books_with_emotions.csv", index=False)
